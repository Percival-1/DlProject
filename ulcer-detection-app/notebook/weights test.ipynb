# %%
from ultralytics import YOLO

model = YOLO("best.pt")
results = model("Screenshot 2025-12-18 192844.png", conf=0.25)
results[0].show()
# Out:
# image 1/1 d:\DlProject\ulcer-detection-app\notebook\Screenshot 2025-12-18 192844.png: 448x640 1 FootUlcer, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
