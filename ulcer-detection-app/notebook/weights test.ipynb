# %%
from ultralytics import YOLO

model = YOLO("weights.pt")
results = model("0010_png.rf.f02ac3acdad8cbe40ed723434430df48.jpg", conf=0.25)
results[0].show()
# Out:
# image 1/1 d:\DlProject\ulcer-detection-app\notebook\0010_png.rf.f02ac3acdad8cbe40ed723434430df48.jpg: 640x640 1 ulcer detection uisng segmentati - v2 2025-12-18 5-02pm, 57.7ms
# Speed: 5.1ms preprocess, 57.7ms inference, 27.7ms postprocess per image at shape (1, 3, 640, 640)
